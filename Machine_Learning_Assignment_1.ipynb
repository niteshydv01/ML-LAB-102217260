# %% [markdown]
# <a href="https://colab.research.google.com/github/niteshydv01/Machine-Learning-assignment/blob/main/Machine_Learning_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment-1 Based on NumPy
#
#
# Q1: Questions on Basic NumPy Array
#
# (a) Reverse the NumPy array: arr = np.array([1, 2, 3, 6, 4, 5])
#
# (b) Flatten the NumPy arr: array1 = np.array([[1, 2, 3], [2, 4, 5], [1, 2, 3]]) using any two
# NumPy in-built methods
#
# (c) Compare the following numpy arrays:
#
# (d) Find the most frequent value and their indice(s) in the following arrays:
#  arr1 = np.array([[1, 2], [3, 4]]) arr2 = np.array([[1, 2], [3, 4]])
# i. ii.
#
# (e) For the i.
# ii. iii.
#
# x = np.array([1,2,3,4,5,1,2,1,1,1])
# y = np.array([1, 1, 1, 2, 3, 4, 2, 4, 3, 3, ])
# array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), find Sum of all elements
# Sum of all elements row-wise
# Sum of all elements column-wise
#
# (f) For the matrix: n_array = np.array([[55, 25, 15],[30, 44, 2],[11, 45, 77]]), find
# i. ii. iii. iv. v.
# i. ii.
# Sum of diagonal elements Eigen values of matrix Eigen vectors of matrix Inverse of matrix Determinant of matrix
# p = [[1, 2], [2, 3]] q = [[4, 5], [6, 7]]
# p = [[1, 2], [2, 3], [4, 5]]
#
#
# (g) Multiply the following matrices and also find covariance between matrices using NumPy:
# q = [[4, 5, 1], [6, 7, 2]]
#
# (h) For the matrices: x = np.array([[2, 3, 4], [3, 2, 9]]); y = np.array([[1, 5, 0], [5, 10, 3]]),
#
# find inner, outer and cartesian product?
#
# Q2: Based on NumPy Mathematics and Statistics
# (a)
# i. ii.
# iii.
# For the array: array = np.array([[1, -2, 3],[-4, 5, -6]])
# Find element-wise absolute value
# Find the 25th, 50th, and 75th percentile of flattened array, for each column, for each row.
# Mean, Median and Standard Deviation of flattened array, of each column, and each row
#
# (b) For the array: a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0]). Find floor, ceiling
# and truncated value, rounded values
#
# Q3: Based on Searching and Sorting
# (a) For the array: array = np.array([10, 52, 62, 16, 16, 54, 453]), find i. Sorted array
#
# ii. Indices of sorted array iii. 4 smallest elements iv. 5 largest elements
# (b) For the array: array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0]), find i. Integer elements only
#
# ii. Float elements only
# Q4:
#
# (a) Write a function named img_to_array(path) that reads an image from a specified path and save it as text file on local machine? (Note: use separate cases for RGB and Grey Scale images)
#
# (b) Load the saved file into jupyter notebook?

# %%
import numpy as np

arr = np.array([1, 2, 3, 6, 4, 5])
reversed_arr = arr[::-1]
print(reversed_arr)
# Out:
# [5 4 6 3 2 1]

# %%
array1 = np.array([[1, 2, 3], [2, 4, 5], [1, 2, 3]])

# Method 1: Using flatten()
flattened_array1 = array1.flatten()

# Method 2: Using ravel()
flattened_array2 = array1.ravel()

print(flattened_array1)
print(flattened_array2)
# Out:
# [1 2 3 2 4 5 1 2 3]
# [1 2 3 2 4 5 1 2 3]

# %%
arr1 = np.array([[1, 2], [3, 4]])
arr2 = np.array([[1, 2], [3, 4]])

# Check if arrays are equal
are_equal = np.array_equal(arr1, arr2)
print(are_equal)
# Out:
# True

# %%
x = np.array([1,2,3,4,5,1,2,1,1,1])
y = np.array([1, 1, 1, 2, 3, 4, 2, 4, 3, 3])

# Find the most frequent value in x
most_freq_value_x = np.bincount(x).argmax()
indices_x = np.where(x == most_freq_value_x)[0]

# Find the most frequent value in y
most_freq_value_y = np.bincount(y).argmax()
indices_y = np.where(y == most_freq_value_y)[0]

print("Most frequent value in x:", most_freq_value_x, "at indices", indices_x)
print("Most frequent value in y:", most_freq_value_y, "at indices", indices_y)
# Out:
# Most frequent value in x: 1 at indices [0 5 7 8 9]
# Most frequent value in y: 1 at indices [0 1 2]

# %%
gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')

# Sum of all elements
total_sum = np.sum(gfg)

# Sum row-wise
row_sum = np.sum(gfg, axis=1)

# Sum column-wise
column_sum = np.sum(gfg, axis=0)

print(total_sum, row_sum, column_sum)
# Out:
# 45 [[14]
#  [16]
#  [15]] [[20  9 16]]

# %%
n_array = np.array([[55, 25, 15],[30, 44, 2],[11, 45, 77]])

# Sum of diagonal elements
diag_sum = np.trace(n_array)

# Eigenvalues and Eigenvectors
eigen_values, eigen_vectors = np.linalg.eig(n_array)

# Inverse of matrix
inverse = np.linalg.inv(n_array)

# Determinant of matrix
determinant = np.linalg.det(n_array)

print(diag_sum, eigen_values, eigen_vectors, inverse, determinant)
# Out:
# 176 [98.16835147 28.097044   49.73460452] [[ 0.4574917   0.34637121 -0.15017693]
#  [ 0.28447814 -0.72784061 -0.4852124 ]
#  [ 0.84248058  0.59184038  0.8614034 ]] [[ 0.02404141 -0.00911212 -0.00444671]
#  [-0.01667882  0.02966905  0.0024785 ]
#  [ 0.00631287 -0.01603732  0.01217379]] 137180.0000000001

# %%
p = np.array([[1, 2], [2, 3]])
q = np.array([[4, 5], [6, 7]])

# Multiply matrices
matrix_product = np.dot(p, q)

# Covariance
covariance = np.cov(p.flatten(), q.flatten())

print(matrix_product, covariance)
# Out:
# [[16 19]
#  [26 31]] [[0.66666667 1.        ]
#  [1.         1.66666667]]

# %%
x = np.array([[2, 3, 4], [3, 2, 9]])
y = np.array([[1, 5, 0], [5, 10, 3]])

# Inner product
inner_product = np.inner(x, y)

# Outer product
outer_product = np.outer(x, y)

# Cartesian product (flattened outer product)
cartesian_product = np.array([(a, b) for a in x.flatten() for b in y.flatten()])

print(inner_product, outer_product, cartesian_product)
# Out:
# [[17 52]
#  [13 62]] [[ 2 10  0 10 20  6]
#  [ 3 15  0 15 30  9]
#  [ 4 20  0 20 40 12]
#  [ 3 15  0 15 30  9]
#  [ 2 10  0 10 20  6]
#  [ 9 45  0 45 90 27]] [[ 2  1]
#  [ 2  5]
#  [ 2  0]
#  [ 2  5]
#  [ 2 10]
#  [ 2  3]
#  [ 3  1]
#  [ 3  5]
#  [ 3  0]
#  [ 3  5]
#  [ 3 10]
#  [ 3  3]
#  [ 4  1]
#  [ 4  5]
#  [ 4  0]
#  [ 4  5]
#  [ 4 10]
#  [ 4  3]
#  [ 3  1]
#  [ 3  5]
#  [ 3  0]
#  [ 3  5]
#  [ 3 10]
#  [ 3  3]
#  [ 2  1]
#  [ 2  5]
#  [ 2  0]
#  [ 2  5]
#  [ 2 10]
#  [ 2  3]
#  [ 9  1]
#  [ 9  5]
#  [ 9  0]
#  [ 9  5]
#  [ 9 10]
#  [ 9  3]]

# %%
array = np.array([[1, -2, 3],[-4, 5, -6]])

# Element-wise absolute value
abs_array = np.abs(array)

# Percentiles
percentiles_flattened = np.percentile(array.flatten(), [25, 50, 75])
percentiles_column = np.percentile(array, [25, 50, 75], axis=0)
percentiles_row = np.percentile(array, [25, 50, 75], axis=1)

# Mean, Median, Standard Deviation
mean_flattened = np.mean(array.flatten())
median_flattened = np.median(array.flatten())
std_flattened = np.std(array.flatten())

mean_column = np.mean(array, axis=0)
median_column = np.median(array, axis=0)
std_column = np.std(array, axis=0)

mean_row = np.mean(array, axis=1)
median_row = np.median(array, axis=1)
std_row = np.std(array, axis=1)

print(abs_array, percentiles_flattened, mean_flattened, median_flattened, std_flattened)
# Out:
# [[1 2 3]
#  [4 5 6]] [-3.5 -0.5  2.5] -0.5 -0.5 3.8622100754188224

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0])

floor_values = np.floor(a)
ceil_values = np.ceil(a)
truncated_values = np.trunc(a)
rounded_values = np.round(a)

print(floor_values, ceil_values, truncated_values, rounded_values)
# Out:
# [-2. -2. -1.  0.  1.  1.  3.] [-1. -1. -0.  1.  2.  2.  3.] [-1. -1. -0.  0.  1.  1.  3.] [-2. -2. -0.  0.  2.  2.  3.]

# %%
array = np.array([10, 52, 62, 16, 16, 54, 453])

# Sorted array
sorted_array = np.sort(array)

# Indices of sorted array
sorted_indices = np.argsort(array)

# 4 smallest elements
smallest_elements = np.partition(array, 4)[:4]

# 5 largest elements
largest_elements = np.partition(array, -5)[-5:]

print(sorted_array, sorted_indices, smallest_elements, largest_elements)
# Out:
# [ 10  16  16  52  54  62 453] [0 3 4 1 5 2 6] [16 10 16 52] [ 16  52  62  54 453]

# %%
array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])

# Integer elements only
integer_elements = array[array == array.astype(int)]

# Float elements only
float_elements = array[array != array.astype(int)]

print(integer_elements, float_elements)
# Out:
# [1. 2. 3. 2.] [1.2 2.2]

# %%
from PIL import Image
import numpy as np

def img_to_array(path):
    img = Image.open(path)
    img_array = np.array(img)

    if img.mode == 'RGB':
        np.savetxt('image_rgb.txt', img_array.reshape(-1, 3), fmt='%d')
    elif img.mode == 'L':
        np.savetxt('image_grey.txt', img_array, fmt='%d')

# Call the function with the path to an image
img_to_array('/content/338137417_172878452252056_8051241462967476920_n.jpg')

# %%
# For RGB image
img_array_rgb = np.loadtxt('image_rgb.txt').reshape((-1, 3))

# For GreyScale image
#img_array_grey = np.loadtxt('image_grey.txt')

print(img_array_rgb)
# Out:
# [[147. 134. 126.]
#  [145. 132. 124.]
#  [142. 129. 121.]
#  ...
#  [255. 255. 255.]
#  [255. 255. 255.]
#  [255. 255. 255.]]

# %%
# !pip install opencv-python
import cv2

# %%
img=cv2.imread('/content/338137417_172878452252056_8051241462967476920_n.jpg')

# %%
print(img)
# Out:
# [[[126 134 147]
#   [124 132 145]
#   [121 129 142]
#   ...
#   [ 62  70  83]
#   [ 57  65  78]
#   [ 55  63  76]]
#
#  [[126 134 147]
#   [124 132 145]
#   [121 129 142]
#   ...
#   [ 65  73  86]
#   [ 61  69  82]
#   [ 59  67  80]]
#
#  [[126 134 147]
#   [125 133 146]
#   [122 130 143]
#   ...
#   [ 70  78  91]
#   [ 67  75  88]
#   [ 66  74  87]]
#
#  ...
#
#  [[250 250 250]
#   [250 250 250]
#   [251 251 251]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[251 251 251]
#   [251 251 251]
#   [252 252 252]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[253 253 253]
#   [253 253 253]
#   [253 253 253]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
import matplotlib.pyplot as plt

# Read the image using OpenCV
img = cv2.imread('/content/338137417_172878452252056_8051241462967476920_n.jpg')

# Convert the image from BGR (OpenCV default) to RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image using Matplotlib
plt.imshow(img)
#plt.axis('off')  # Hide axis
plt.show()

# %%
plt.imshow(img_rgb)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
